# %%
#pip install ultralytics

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolo-Weights\yolov8n.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 7.95MB/s]
# 0: 480x640 1 person, 2 chairs, 575.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.3
# Class name --> chair
# Speed: 10.9ms preprocess, 575.9ms inference, 21.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 386.5ms
# Confidence ---> 0.6
# Class name --> chair
# Speed: 16.7ms preprocess, 386.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 412.5ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 24.9ms preprocess, 412.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 503.4ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 16.7ms preprocess, 503.4ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 254.2ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 5.5ms preprocess, 254.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 283.5ms
# Confidence ---> 0.75
# Class name --> chair
# Speed: 14.7ms preprocess, 283.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 252.6ms
# Confidence ---> 0.76
# Class name --> chair
# Speed: 18.7ms preprocess, 252.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.6ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 16.3ms preprocess, 232.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 251.3ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 10.6ms preprocess, 251.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 273.0ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 8.1ms preprocess, 273.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 224.4ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 6.8ms preprocess, 224.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 283.5ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 5.1ms preprocess, 283.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 279.9ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 15.8ms preprocess, 279.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 318.6ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 13.3ms preprocess, 318.6ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 310.0ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 5.6ms preprocess, 310.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 300.2ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 26.0ms preprocess, 300.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 335.3ms
# Confidence ---> 0.76
# Class name --> chair
# Speed: 6.6ms preprocess, 335.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 310.7ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 18.3ms preprocess, 310.7ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 257.6ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 8.1ms preprocess, 257.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 293.1ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 29.9ms preprocess, 293.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 298.3ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 13.0ms preprocess, 298.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 227.5ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 10.6ms preprocess, 227.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 227.6ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 6.6ms preprocess, 227.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 212.8ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 4.0ms preprocess, 212.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 264.8ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 4.5ms preprocess, 264.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 262.9ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 5.8ms preprocess, 262.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 288.3ms
# Confidence ---> 0.76
# Class name --> chair
# Speed: 6.1ms preprocess, 288.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 233.4ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 6.5ms preprocess, 233.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 216.2ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 10.1ms preprocess, 216.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 222.9ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 4.0ms preprocess, 222.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 295.0ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 5.6ms preprocess, 295.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 343.3ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 6.1ms preprocess, 343.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 209.9ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 7.1ms preprocess, 209.9ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 199.7ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 2.5ms preprocess, 199.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 191.9ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 4.5ms preprocess, 191.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 170.3ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 3.5ms preprocess, 170.3ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 171.6ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 5.7ms preprocess, 171.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 172.2ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 5.1ms preprocess, 172.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 182.2ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 6.0ms preprocess, 182.2ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 174.0ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 3.0ms preprocess, 174.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 231.9ms
# Confidence ---> 0.63
# Class name --> chair
# Speed: 3.5ms preprocess, 231.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.8ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 18.4ms preprocess, 232.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 229.9ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 16.3ms preprocess, 229.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 potted plant, 218.0ms
# Confidence ---> 0.68
# Class name --> chair
# Confidence ---> 0.27
# Class name --> pottedplant
# Speed: 15.8ms preprocess, 218.0ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 220.1ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 6.1ms preprocess, 220.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 198.5ms
# Confidence ---> 0.75
# Class name --> chair
# Speed: 4.6ms preprocess, 198.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 226.9ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 3.5ms preprocess, 226.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 190.3ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 11.7ms preprocess, 190.3ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 203.6ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 4.5ms preprocess, 203.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 204.8ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 4.0ms preprocess, 204.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 189.6ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 3.5ms preprocess, 189.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 218.3ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 3.6ms preprocess, 218.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 220.8ms
# Confidence ---> 0.57
# Class name --> chair
# Speed: 5.0ms preprocess, 220.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 224.7ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 4.5ms preprocess, 224.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 213.8ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 5.1ms preprocess, 213.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 231.6ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 5.6ms preprocess, 231.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 217.8ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 3.6ms preprocess, 217.8ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 281.9ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 5.5ms preprocess, 281.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 267.3ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 5.1ms preprocess, 267.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 270.8ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 4.0ms preprocess, 270.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 265.6ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 5.4ms preprocess, 265.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 247.3ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 14.8ms preprocess, 247.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 247.0ms
# Confidence ---> 0.77
# Class name --> chair
# Speed: 6.6ms preprocess, 247.0ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 255.7ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 3.5ms preprocess, 255.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 238.9ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 8.1ms preprocess, 238.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 208.4ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 13.2ms preprocess, 208.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 274.6ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 7.6ms preprocess, 274.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 243.8ms
# Confidence ---> 0.75
# Class name --> chair
# Speed: 5.8ms preprocess, 243.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 391.3ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 3.0ms preprocess, 391.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 253.8ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 3.5ms preprocess, 253.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 218.1ms
# Confidence ---> 0.63
# Class name --> chair
# Speed: 3.0ms preprocess, 218.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 267.7ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 15.9ms preprocess, 267.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 potted plant, 249.9ms
# Confidence ---> 0.71
# Class name --> chair
# Confidence ---> 0.46
# Class name --> pottedplant
# Speed: 13.0ms preprocess, 249.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 254.1ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 6.8ms preprocess, 254.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 250.8ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 4.5ms preprocess, 250.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 237.7ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 6.9ms preprocess, 237.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 268.2ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 13.3ms preprocess, 268.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 235.0ms
# Confidence ---> 0.75
# Class name --> chair
# Speed: 13.9ms preprocess, 235.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 246.0ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 20.4ms preprocess, 246.0ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 228.7ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 3.0ms preprocess, 228.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 chairs, 225.8ms
# Confidence ---> 0.71
# Class name --> chair
# Confidence ---> 0.29
# Class name --> chair
# Speed: 7.1ms preprocess, 225.8ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 213.9ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 4.0ms preprocess, 213.9ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 223.9ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 5.5ms preprocess, 223.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 206.8ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 12.8ms preprocess, 206.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 229.5ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 4.5ms preprocess, 229.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 220.5ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 4.6ms preprocess, 220.5ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 277.8ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 6.1ms preprocess, 277.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 245.4ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 10.6ms preprocess, 245.4ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 265.5ms
# Confidence ---> 0.63
# Class name --> chair
# Speed: 5.5ms preprocess, 265.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 243.8ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 10.2ms preprocess, 243.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 271.5ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 15.5ms preprocess, 271.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 273.5ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 6.1ms preprocess, 273.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 251.2ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 8.6ms preprocess, 251.2ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 390.6ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 3.9ms preprocess, 390.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 275.0ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 14.2ms preprocess, 275.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 262.5ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 9.8ms preprocess, 262.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 262.3ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 3.5ms preprocess, 262.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 265.9ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 5.5ms preprocess, 265.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 240.7ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 7.1ms preprocess, 240.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 274.9ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 5.0ms preprocess, 274.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 271.7ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 4.5ms preprocess, 271.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 275.7ms
# Confidence ---> 0.76
# Class name --> chair
# Speed: 6.5ms preprocess, 275.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 325.6ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 5.1ms preprocess, 325.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 261.5ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 5.5ms preprocess, 261.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 240.5ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 7.1ms preprocess, 240.5ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 278.8ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 5.0ms preprocess, 278.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.1ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 4.5ms preprocess, 232.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 202.5ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 4.8ms preprocess, 202.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 213.8ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 4.5ms preprocess, 213.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 206.5ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 4.0ms preprocess, 206.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 193.7ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 4.5ms preprocess, 193.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 188.2ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 2.5ms preprocess, 188.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 220.6ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 11.6ms preprocess, 220.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 332.8ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 5.1ms preprocess, 332.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 245.0ms
# Confidence ---> 0.76
# Class name --> chair
# Speed: 12.1ms preprocess, 245.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 243.1ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 10.6ms preprocess, 243.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 246.7ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 3.6ms preprocess, 246.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 210.7ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 5.1ms preprocess, 210.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 227.8ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 4.0ms preprocess, 227.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 210.2ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 10.9ms preprocess, 210.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 235.1ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 4.6ms preprocess, 235.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 230.4ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 12.8ms preprocess, 230.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 202.8ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 4.0ms preprocess, 202.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 193.6ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 3.0ms preprocess, 193.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 217.1ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 4.0ms preprocess, 217.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 198.7ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 4.0ms preprocess, 198.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 198.5ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 3.0ms preprocess, 198.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 potted plant, 198.7ms
# Confidence ---> 0.69
# Class name --> chair
# Confidence ---> 0.27
# Class name --> pottedplant
# Speed: 4.0ms preprocess, 198.7ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 191.6ms
# Confidence ---> 0.61
# Class name --> chair
# Speed: 2.5ms preprocess, 191.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 208.2ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 5.1ms preprocess, 208.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 393.4ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 3.5ms preprocess, 393.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.7ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 4.5ms preprocess, 232.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 251.0ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 5.6ms preprocess, 251.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 233.8ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 9.5ms preprocess, 233.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 224.6ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 4.0ms preprocess, 224.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 243.6ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 23.6ms preprocess, 243.6ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 264.6ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 4.0ms preprocess, 264.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 222.6ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 5.6ms preprocess, 222.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 219.8ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 4.0ms preprocess, 219.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 200.3ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 4.0ms preprocess, 200.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 211.8ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 3.6ms preprocess, 211.8ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 238.3ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 4.0ms preprocess, 238.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 249.8ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 9.6ms preprocess, 249.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 199.5ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 3.5ms preprocess, 199.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 195.7ms
# Confidence ---> 0.63
# Class name --> chair
# Speed: 4.5ms preprocess, 195.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 336.3ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 7.8ms preprocess, 336.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 235.2ms
# Confidence ---> 0.58
# Class name --> chair
# Speed: 8.1ms preprocess, 235.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 226.2ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 4.1ms preprocess, 226.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 245.5ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 11.2ms preprocess, 245.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 218.0ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 5.6ms preprocess, 218.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 218.8ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 5.1ms preprocess, 218.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 224.2ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 2.5ms preprocess, 224.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.6ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 11.7ms preprocess, 232.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 221.3ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 3.0ms preprocess, 221.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 236.8ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 11.6ms preprocess, 236.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 201.2ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 5.0ms preprocess, 201.2ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 206.2ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 3.5ms preprocess, 206.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 189.1ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 5.1ms preprocess, 189.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 223.7ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 4.1ms preprocess, 223.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 386.1ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 5.6ms preprocess, 386.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.9ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 4.0ms preprocess, 232.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 268.7ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 6.0ms preprocess, 268.7ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 214.9ms
# Confidence ---> 0.6
# Class name --> chair
# Speed: 13.4ms preprocess, 214.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 237.2ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 3.5ms preprocess, 237.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 229.9ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 11.2ms preprocess, 229.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 213.3ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 12.7ms preprocess, 213.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 238.0ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 6.1ms preprocess, 238.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 235.9ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 6.1ms preprocess, 235.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 250.0ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 12.7ms preprocess, 250.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.4ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 5.8ms preprocess, 232.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 214.8ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 3.6ms preprocess, 214.8ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 395.9ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 4.1ms preprocess, 395.9ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 257.4ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 14.5ms preprocess, 257.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 potted plant, 217.1ms
# Confidence ---> 0.74
# Class name --> chair
# Confidence ---> 0.26
# Class name --> pottedplant
# Speed: 3.5ms preprocess, 217.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 241.6ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 14.4ms preprocess, 241.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 227.4ms
# Confidence ---> 0.61
# Class name --> chair
# Speed: 6.1ms preprocess, 227.4ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 262.2ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 4.0ms preprocess, 262.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 264.7ms
# Confidence ---> 0.59
# Class name --> chair
# Speed: 7.3ms preprocess, 264.7ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 274.1ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 6.1ms preprocess, 274.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 310.1ms
# Confidence ---> 0.76
# Class name --> chair
# Speed: 10.6ms preprocess, 310.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 363.7ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 4.0ms preprocess, 363.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 282.6ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 16.6ms preprocess, 282.6ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 275.6ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 5.0ms preprocess, 275.6ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 401.7ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 5.5ms preprocess, 401.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 233.9ms
# Confidence ---> 0.77
# Class name --> chair
# Speed: 4.0ms preprocess, 233.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 potted plant, 230.6ms
# Confidence ---> 0.71
# Class name --> chair
# Confidence ---> 0.31
# Class name --> pottedplant
# Speed: 5.6ms preprocess, 230.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 224.7ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 4.1ms preprocess, 224.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 237.5ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 5.6ms preprocess, 237.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 220.6ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 11.8ms preprocess, 220.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 305.8ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 2.5ms preprocess, 305.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 292.8ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 5.1ms preprocess, 292.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 241.6ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 9.2ms preprocess, 241.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 261.9ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 5.6ms preprocess, 261.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 273.8ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 6.1ms preprocess, 273.8ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 439.5ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 4.6ms preprocess, 439.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 289.3ms
# Confidence ---> 0.6
# Class name --> chair
# Speed: 5.5ms preprocess, 289.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 238.2ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 13.9ms preprocess, 238.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 270.6ms
# Confidence ---> 0.63
# Class name --> chair
# Speed: 12.8ms preprocess, 270.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 257.2ms
# Confidence ---> 0.61
# Class name --> chair
# Speed: 6.6ms preprocess, 257.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 259.0ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 3.0ms preprocess, 259.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 251.9ms
# Confidence ---> 0.63
# Class name --> chair
# Speed: 3.0ms preprocess, 251.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 236.4ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 12.2ms preprocess, 236.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 253.7ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 4.0ms preprocess, 253.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 312.4ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 11.1ms preprocess, 312.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 332.4ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 9.8ms preprocess, 332.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 508.2ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 6.6ms preprocess, 508.2ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 348.4ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 5.1ms preprocess, 348.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 277.9ms
# Confidence ---> 0.76
# Class name --> chair
# Speed: 13.4ms preprocess, 277.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 236.2ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 5.2ms preprocess, 236.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 234.5ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 5.6ms preprocess, 234.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 222.3ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 3.6ms preprocess, 222.3ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.0ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 11.2ms preprocess, 232.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 230.0ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 2.5ms preprocess, 230.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 272.6ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 9.1ms preprocess, 272.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 239.0ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 6.1ms preprocess, 239.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 296.0ms
# Confidence ---> 0.65
# Class name --> chair
# Speed: 5.0ms preprocess, 296.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 potted plant, 441.4ms
# Confidence ---> 0.75
# Class name --> chair
# Confidence ---> 0.27
# Class name --> pottedplant
# Speed: 13.2ms preprocess, 441.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 239.3ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 7.7ms preprocess, 239.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 239.8ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 6.2ms preprocess, 239.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 235.4ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 12.8ms preprocess, 235.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 258.1ms
# Confidence ---> 0.79
# Class name --> chair
# Speed: 3.5ms preprocess, 258.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 234.9ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 6.4ms preprocess, 234.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 246.0ms
# Confidence ---> 0.73
# Class name --> chair
# Speed: 5.0ms preprocess, 246.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 248.1ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 4.0ms preprocess, 248.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 219.1ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 4.0ms preprocess, 219.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 217.3ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 4.0ms preprocess, 217.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 354.1ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 4.0ms preprocess, 354.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 210.0ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 9.8ms preprocess, 210.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 182.0ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 12.5ms preprocess, 182.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 210.8ms
# Confidence ---> 0.68
# Class name --> chair
# Speed: 3.5ms preprocess, 210.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 229.1ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 5.1ms preprocess, 229.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 240.9ms
# Confidence ---> 0.64
# Class name --> chair
# Speed: 13.3ms preprocess, 240.9ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 232.3ms
# Confidence ---> 0.69
# Class name --> chair
# Speed: 5.0ms preprocess, 232.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 222.9ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 3.0ms preprocess, 222.9ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 potted plant, 219.5ms
# Confidence ---> 0.75
# Class name --> chair
# Confidence ---> 0.26
# Class name --> pottedplant
# Speed: 4.6ms preprocess, 219.5ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 269.3ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 4.5ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 potted plant, 362.8ms
# Confidence ---> 0.58
# Class name --> chair
# Confidence ---> 0.26
# Class name --> pottedplant
# Speed: 6.6ms preprocess, 362.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 200.8ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 5.1ms preprocess, 200.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 214.0ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 6.6ms preprocess, 214.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 230.8ms
# Confidence ---> 0.76
# Class name --> chair
# Speed: 3.0ms preprocess, 230.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 204.4ms
# Confidence ---> 0.6
# Class name --> chair
# Speed: 4.6ms preprocess, 204.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 198.9ms
# Confidence ---> 0.77
# Class name --> chair
# Speed: 5.1ms preprocess, 198.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 204.1ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 5.9ms preprocess, 204.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 219.7ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 3.5ms preprocess, 219.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 193.6ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 3.5ms preprocess, 193.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 403.2ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 5.1ms preprocess, 403.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 289.3ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 11.9ms preprocess, 289.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 286.0ms
# Confidence ---> 0.7
# Class name --> chair
# Speed: 9.6ms preprocess, 286.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 291.9ms
# Confidence ---> 0.72
# Class name --> chair
# Speed: 7.6ms preprocess, 291.9ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 361.5ms
# Confidence ---> 0.74
# Class name --> chair
# Speed: 3.4ms preprocess, 361.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 292.5ms
# Confidence ---> 0.71
# Class name --> chair
# Speed: 10.4ms preprocess, 292.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 278.5ms
# Confidence ---> 0.66
# Class name --> chair
# Speed: 4.4ms preprocess, 278.5ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 256.7ms
# Confidence ---> 0.75
# Class name --> chair
# Speed: 4.8ms preprocess, 256.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 234.0ms
# Confidence ---> 0.67
# Class name --> chair
# Speed: 6.7ms preprocess, 234.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 356.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.68
# Class name --> chair
# Speed: 3.3ms preprocess, 356.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 228.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.36
# Class name --> suitcase
# Speed: 12.8ms preprocess, 228.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 257.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.43
# Class name --> suitcase
# Speed: 3.5ms preprocess, 257.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 249.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 12.8ms preprocess, 249.0ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 351.4ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.53
# Class name --> suitcase
# Speed: 6.1ms preprocess, 351.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 283.2ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.29
# Class name --> suitcase
# Speed: 12.2ms preprocess, 283.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 266.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.39
# Class name --> suitcase
# Speed: 4.5ms preprocess, 266.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 267.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 5.1ms preprocess, 267.9ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 250.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Speed: 5.6ms preprocess, 250.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 1 chair, 404.5ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.26
# Class name --> suitcase
# Speed: 5.5ms preprocess, 404.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 1 chair, 210.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.48
# Class name --> suitcase
# Speed: 5.5ms preprocess, 210.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 200.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.66
# Class name --> chair
# Speed: 4.0ms preprocess, 200.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 210.8ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.61
# Class name --> chair
# Speed: 6.6ms preprocess, 210.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 226.7ms
# Confidence ---> 0.75
# Class name --> chair
# Speed: 10.2ms preprocess, 226.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 215.2ms
# Confidence ---> 0.62
# Class name --> chair
# Speed: 6.0ms preprocess, 215.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 209.3ms
# Confidence ---> 0.65
# Class name --> chair
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 4.5ms preprocess, 209.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 228.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.67
# Class name --> chair
# Speed: 4.0ms preprocess, 228.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 227.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.75
# Class name --> chair
# Speed: 2.6ms preprocess, 227.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 416.9ms
# Confidence ---> 0.88
# ...
# Class name --> person
# Confidence ---> 0.57
# Class name --> chair
# Speed: 3.5ms preprocess, 414.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 303.7ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 8.1ms preprocess, 303.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 265.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Speed: 3.9ms preprocess, 265.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 215.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.48
# Class name --> chair
# Speed: 6.1ms preprocess, 215.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 369.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.43
# Class name --> chair
# Speed: 5.0ms preprocess, 369.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 265.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.33
# Class name --> chair
# Speed: 6.7ms preprocess, 265.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 251.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 9.8ms preprocess, 251.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 311.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> chair
# Speed: 4.3ms preprocess, 311.6ms inference, 11.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 560.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.29
# Class name --> sofa
# Speed: 5.6ms preprocess, 560.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 399.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.43
# Class name --> chair
# Speed: 6.6ms preprocess, 399.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 333.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Confidence ---> 0.29
# Class name --> chair
# Speed: 7.6ms preprocess, 333.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 couch, 279.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.32
# Class name --> sofa
# Speed: 7.0ms preprocess, 279.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 262.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Speed: 7.3ms preprocess, 262.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 346.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.36
# Class name --> sofa
# Confidence ---> 0.33
# Class name --> chair
# Speed: 68.3ms preprocess, 346.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 237.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.37
# Class name --> sofa
# Speed: 12.9ms preprocess, 237.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 219.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.43
# Class name --> chair
# Confidence ---> 0.35
# Class name --> sofa
# Speed: 6.0ms preprocess, 219.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 240.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.3
# Class name --> sofa
# Speed: 10.2ms preprocess, 240.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 347.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.36
# Class name --> sofa
# Speed: 8.1ms preprocess, 347.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 299.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.29
# Class name --> sofa
# Speed: 6.1ms preprocess, 299.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 255.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.37
# Class name --> sofa
# Confidence ---> 0.34
# Class name --> chair
# Speed: 9.7ms preprocess, 255.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 271.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.46
# Class name --> chair
# Confidence ---> 0.31
# Class name --> sofa
# Speed: 3.0ms preprocess, 271.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 263.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.27
# Class name --> chair
# Speed: 3.5ms preprocess, 263.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 439.9ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.56
# Class name --> chair
# Confidence ---> 0.32
# Class name --> sofa
# Speed: 8.3ms preprocess, 439.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 262.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.37
# Class name --> chair
# Speed: 5.5ms preprocess, 262.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 280.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.32
# Class name --> chair
# Confidence ---> 0.31
# Class name --> sofa
# Speed: 12.0ms preprocess, 280.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 235.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.37
# Class name --> chair
# Confidence ---> 0.37
# Class name --> sofa
# Speed: 11.7ms preprocess, 235.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 221.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.38
# Class name --> sofa
# Confidence ---> 0.35
# Class name --> chair
# Speed: 4.6ms preprocess, 221.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 410.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.39
# Class name --> sofa
# Confidence ---> 0.38
# Class name --> chair
# Speed: 9.7ms preprocess, 410.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 214.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.31
# Class name --> sofa
# Speed: 3.9ms preprocess, 214.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 couch, 216.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.35
# Class name --> sofa
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.29
# Class name --> chair
# Speed: 3.5ms preprocess, 216.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 couch, 224.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.43
# Class name --> sofa
# Confidence ---> 0.29
# Class name --> chair
# Speed: 3.0ms preprocess, 224.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 240.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.46
# Class name --> sofa
# Speed: 3.5ms preprocess, 240.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 couch, 344.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.46
# Class name --> sofa
# Confidence ---> 0.28
# Class name --> chair
# Speed: 4.5ms preprocess, 344.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 304.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 8.1ms preprocess, 304.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 2 chairs, 237.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.34
# Class name --> cup
# Confidence ---> 0.32
# Class name --> chair
# Speed: 4.6ms preprocess, 237.4ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 261.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Confidence ---> 0.27
# Class name --> chair
# Speed: 5.1ms preprocess, 261.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 239.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.66
# Class name --> chair
# Speed: 4.0ms preprocess, 239.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 243.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.58
# Class name --> chair
# Speed: 10.4ms preprocess, 243.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 344.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.39
# Class name --> chair
# Speed: 5.0ms preprocess, 344.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 259.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.67
# Class name --> chair
# Speed: 8.1ms preprocess, 259.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 200.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.56
# Class name --> chair
# Speed: 4.5ms preprocess, 200.5ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 228.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Speed: 4.0ms preprocess, 228.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1770.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.53
# Class name --> chair
# Speed: 9.8ms preprocess, 1770.6ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 951.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Confidence ---> 0.29
# Class name --> chair
# Speed: 29.9ms preprocess, 951.3ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 571.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Speed: 7.6ms preprocess, 571.2ms inference, 11.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 525.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 7.4ms preprocess, 525.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 684.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
# Speed: 8.0ms preprocess, 684.1ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 769.8ms
# Confidence ---> 0.82
# Class name --> person
# Speed: 7.8ms preprocess, 769.8ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 442.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.47
# Class name --> chair
# Confidence ---> 0.43
# Class name --> chair
# Speed: 18.3ms preprocess, 442.2ms inference, 14.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 438.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Speed: 15.9ms preprocess, 438.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 463.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.42
# Class name --> chair
# Confidence ---> 0.36
# Class name --> chair
# Speed: 8.9ms preprocess, 463.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 620.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.54
# Class name --> chair
# Confidence ---> 0.5
# Class name --> chair
# Speed: 5.5ms preprocess, 620.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 418.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.31
# Class name --> chair
# Speed: 6.7ms preprocess, 418.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 465.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.55
# Class name --> chair
# Speed: 11.4ms preprocess, 465.3ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 476.0ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.65
# Class name --> chair
# Confidence ---> 0.41
# Class name --> chair
# Speed: 5.8ms preprocess, 476.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 444.9ms
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.33
# Class name --> chair
# Speed: 16.5ms preprocess, 444.9ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 suitcase, 460.1ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.27
# Class name --> suitcase
# Speed: 5.6ms preprocess, 460.1ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 620.7ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 64.3ms preprocess, 620.7ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 348.2ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 5.6ms preprocess, 348.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 373.6ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 13.1ms preprocess, 373.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 420.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
# Speed: 8.3ms preprocess, 420.2ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 361.5ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 11.0ms preprocess, 361.5ms inference, 12.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 698.8ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.32
# Class name --> chair
# Speed: 7.7ms preprocess, 698.8ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 436.7ms
# Confidence ---> 0.93
# Class name --> person
# Speed: 6.2ms preprocess, 436.7ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 335.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 10.1ms preprocess, 335.7ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 336.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 6.0ms preprocess, 336.4ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\malli\\Documents\\NareshIT\\Python'

# %%
from ultralytics import YOLO

# Load a pre-trained YOLO model
model = YOLO("yolo-Weights/yolov8n.pt")

# Start tracking objects in a video
# You can also use live video streams or webcam input
model.track(source=r"C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\OpenCV\videos\los_angeles_out.mp4")
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Collecting lap>=0.5.12
#   Downloading lap-0.5.12-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\malli\anaconda3\lib\site-packages (from lap>=0.5.12) (1.26.4)
# Downloading lap-0.5.12-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 1.5/1.5 MB 13.5 MB/s eta 0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.12
#
# requirements: AutoUpdate success  41.5s, installed 1 package: ['lap>=0.5.12']
# requirements:  Restart runtime or rerun command for updates to take effect
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       4 model = YOLO("yolo-Weights/yolov8n.pt")
#       6 # Start tracking objects in a video
#       7 # You can also use live video streams or webcam input
# ----> 8 model.track(source=r"C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\OpenCV\videos\los_angeles_out.mp4")
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\model.py:605, in Model.track(self, source, stream, persist, **kwargs)
#     603 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     604 kwargs["mode"] = "track"
# --> 605 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\model.py:558, in Model.predict(self, source, stream, predictor, **kwargs)
#     556 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     557     self.predictor.set_prompts(prompts)
# --> 558 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:175, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     173     return self.stream_inference(source, model, *args, **kwargs)
#     174 else:
# --> 175     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:233, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     229     self.setup_model(model)
#     231 with self._lock:  # for thread-safe inference
#     232     # Setup source every time predict is called
# --> 233     self.setup_source(source if source is not None else self.args.source)
#     235     # Check if save_dir/ label file exists
#     236     if self.args.save or self.args.save_txt:
#
# File ~\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:205, in BasePredictor.setup_source(self, source)
#     195 self.imgsz = check_imgsz(self.args.imgsz, stride=self.model.stride, min_dim=2)  # check image size
#     196 self.transforms = (
#     197     getattr(
#     198         self.model.model,
#    (...)
#     203     else None
#     204 )
# --> 205 self.dataset = load_inference_source(
#     206     source=source,
#     207     batch=self.args.batch,
#     208     vid_stride=self.args.vid_stride,
#     209     buffer=self.args.stream_buffer,
#     210 )
#     211 self.source_type = self.dataset.source_type
#     212 if not getattr(self, "stream", True) and (
#     213     self.source_type.stream
#     214     or self.source_type.screenshot
#     215     or len(self.dataset) > 1000  # many images
#     216     or any(getattr(self.dataset, "video_flag", [False]))
#     217 ):  # videos
#
# File ~\anaconda3\Lib\site-packages\ultralytics\data\build.py:214, in load_inference_source(source, batch, vid_stride, buffer)
#     212     dataset = LoadPilAndNumpy(source)
#     213 else:
# --> 214     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride)
#     216 # Attach source types to the dataset
#     217 setattr(dataset, "source_type", source_type)
#
# File ~\anaconda3\Lib\site-packages\ultralytics\data\loaders.py:341, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride)
#     339         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     340     else:
# --> 341         raise FileNotFoundError(f"{p} does not exist")
#     343 # Define files as images or videos
#     344 images, videos = [], []
#
# FileNotFoundError: C:\Users\omkar\OneDrive\Documents\Data science\Naresh IT\Naresh IT\OpenCV\videos\los_angeles_out.mp4 does not exist

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True
